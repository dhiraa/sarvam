# %% [markdown]
# # [jigsaw-toxic-comment-classification-challenge](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data)
#
# Similar dataset: https://conversationai.github.io/

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../")
import numpy as np
import pandas as pd
# from utils.data.kaggle.spooky_dataset import *
from tc_utils.dataframe import *
import spacy
# Out:
# /home/mageswarand/anaconda3/envs/tensorflow1.0/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ## Dhira Dataset Handler backed by Pandas

# %%
! ls ../data/jigsaw_toxic_comment_classification_challenge/
# Out:
# README.md		   test.csv	 train.csv	train_processed.csv
# sample_submission.csv.zip  test.csv.zip  train.csv.zip

# %%
nlp = spacy.load('en_core_web_sm')

# %%
DATA_STORE_PATH="jigsaw_toxic_comment_classification_challenge_data"
TEXT_COL = "comment_text"
CATEOGORY_COLS = ["toxic","severe_toxic","obscene","threat","insult","identity_hate"]

TRAIN_FILE_PATH = "../data/jigsaw_toxic_comment_classification_challenge/train_processed.json"
TEST_FILE_PATH =  "../data/jigsaw_toxic_comment_classification_challenge/test_processed.json"

# %%
#Prepare the dataset
dataset: TextDataFrame = TextDataFrame(train_file_path=TRAIN_FILE_PATH,
                                       test_file_path=TEST_FILE_PATH,
                                       text_col=TEXT_COL,
                                       category_cols=CATEOGORY_COLS,
                                       dataset_name=DATA_STORE_PATH,
                                       category_col = None, 
                                       max_doc_legth = 100, 
                                       max_word_length = 10,
                                       is_multi_label=True,
                                       is_tokenize=False)
# Out:
# Loading processed files...
# Preparing vocab file...
# No <UNK> token found
# experiments/data//jigsaw_toxic_comment_classification_challenge_data/words_vocab.tsv

# %%
# To get the raw text features:
train_text_data = dataset.get_train_text_data()
val_text_data = dataset.get_val_text_data()
test_tezt_data = dataset.get_test_text_data()

# %%
#To get text word ids
train_text_word_ids = dataset.get_train_text_word_ids()
val_text_word_ids = dataset.get_val_text_word_ids()
# test_text_word_ids = dataset.get_test_text_word_ids()

#To get text word char IDS
train_text_word_char_ids = dataset.get_train_text_word_char_ids()
val_text_word_char_ids = dataset.get_val_text_word_char_ids()
# test_text_word_char_ids = dataset.get_test_text_word_char_ids()
# Out:
# ...
# pad_sequences: 100%|██████████| 4912/4912 [00:00<00:00, 6126.20it/s]

# %%
# To get indexed category labels:
train_label = dataset.get_train_label()
val_label = dataset.get_val_label()
# test_label = dataset.get_test_label()

#To get on-hot encoded labels:
train_one_hot_encoded_label = dataset.get_train_one_hot_label()
val_one_hot_encoded_label= dataset.get_val_one_hot_label()
# dataset.get_one_hot_test_label()

# %%
train_text_word_ids.shape

# %%
train_text_word_char_ids.shape

# %%
dataset.word2id["<UNK>"]

# %% [markdown]
# ### Get Train Data

# %%
train_df = dataset.get_train_data()
train_df.count(), train_df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-d32f7baa370e> in <module>()
# ----> 1 train_df = dataset.get_train_data()
#       2 train_df.count(), train_df.head()
#
# /opt/dhiraa/sarvam/text_classification/tc_utils/dataframe.py in get_train_data(self)
#     553         '''
#     554         if self.train_df_path.endswith("csv"):
# --> 555             full_df = pd.read_csv(self.train_df_path)
#     556         elif self.train_df_path.endswith("json"):
#     557             full_df = pd.read_json(self.train_df_path)
#
# ...

# %% [markdown]
# ### Get Test Data

# %%
test_df = dataset.get_test_df()
test_df.count()
# Out:
# Unnamed: 0      226998
# id              226998
# comment_text    226997
# dtype: int64

# %%
test_df["id"].iloc(46571)

# %%
test_df.loc[test_df["id"] == 206058417140, 'comment_text'] = "Fuck you!"

# %%
text = test_df[test_df["id"] == 206058417140]["comment_text"].values[0]
text
# Out:
# 'Fuck you!'

# %%
nlp(text)
# Out:
# "
#
# Thank you for experimenting with  Wikipedia. Your test worked, and it has been reverted or removed. Please use the sandbox for any other tests you may want to do. Take a look at the welcome page to learn more about contributing to our encyclopedia. A link to the edit I have reverted can be found here: link. If you believe this edit should not have been reverted, please contact me.  ring "

# %%
def tokenize(df: pd.DataFrame, text_col, nlp):
    '''
    In place tokenization on text column
    :param df: Pandas Dataframe
    :param text_col: Text Column
    :return: 
    '''

    if not nlp:
        print_error("Do a global initilization nlp = spacy.load('en_core_web_sm')")
        raise Warning("Initialize nlp = spacy.load('en_core_web_sm')")

    def cleaning(sentence):
        sentence = nlp(sentence)
        tokens = [token.text for token in sentence]
        tokens = ' '.join(tokens)
        return tokens

    # df = df.assign(spacy_processed = lambda rows : rows[text_col].map(lambda row: cleaning(row)))
    data = [cleaning(line) for line in tqdm(df[text_col].tolist())]
    df[text_col] = data
    return df

# %%
def cleaning(ids ,sentence):
    print(ids)
    print(sentence)
    sentence = nlp(sentence)
    tokens = [token.text for token in sentence]
    tokens = ' '.join(tokens)
    return tokens

# %%
 data = [cleaning(line[0], line[1]) for line in tqdm(test_df[["id", "comment_text"]].values.tolist()[46570:])]
# Out:
#   0%|          | 0/180428 [00:00<?, ?it/s]
#
#
#   0%|          | 3/180428 [00:00<2:03:54, 24.27it/s]
# 206025535819
# "
# With pleasure, cunt, and I'll leave you to finish yourself off    Imperatrix Mundi "
# 206029413941
# :What is wrong is that wikipedia is not supposed to engage in original conclusions. And this is a conclusion that is contestable, as this discussion shows. Contestable conclusions should be sourced. If you know of an independent outside source that characterizes the territory of the Netherlands as a "cradle of civilizations", let's put it in there. Otherwise, I don't think it's good idea. I also think that Schonken's tone was entirely inappropriate. I'm not sure what unsourced bias of other nations you are referring to, by the way.
# 206035641213
# You mentined an international site on Croatian history? Where?
# 206058417140
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
from sarvam.eda.meta_features.text import *

# %%
train_df.head()
# Out:
#          id                                       comment_text  toxic  \
# 0  22256635  Nonsense?  kiss off, geek. what I said is true...      1
# 1  27450690  "\n\n Please do not vandalize pages, as you di...      0
# 2  54037174  "\n\n ""Points of interest"" \n\nI removed the...      0
# 3  77493077  Asking some his nationality is a Racial offenc...      0
# 4  79357270  The reader here is not going by my say so for ...      0
#
#    severe_toxic  obscene  threat  insult  identity_hate  num_words
# 0             0        0       0       0              0         16
# 1             0        0       0       0              0         32
# 2             0        0       0       0              0         70
# 3             0        0       0       0              0         26
# 4             0        0       0       0              0         49

# %%
train_df["num_words"] = train_df[TEXT_COL].apply(num_words)

# %%
train_df["max_word_length"] = train_df[TEXT_COL].apply(lambda sentence:
                                                 max([len(word) \
                                                      for word in sentence.split(" ")]))

# %%
print("Total number of training samples: ", len(train_df))
# Out:
# Total number of training samples:  95851

# %%
# Lets see how many documents are greater than MAX_DOC_LENGTH
MAX_DOC_LENGTH = 170
missed_docs = train_df[train_df["num_words"] > MAX_DOC_LENGTH].count()[0]
print("Clipped documents: ", missed_docs/len(train_df) * 100, "%")
# Out:
# Clipped documents:  8.39427861994 %

# %%
# Lets see how many documents are greater than MAX_DOC_LENGTH
MAX_WORD_LENGTH = 15
missed_docs = train_df[train_df["max_word_length"] > MAX_WORD_LENGTH].count()[0]
print("Clipped words: ", missed_docs/len(train_df) * 100, "%")
# Out:
# Clipped documents:  24.3722026896 %

# %%
train_df
