# %% [markdown]
# # Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import nsfg
import first

# %% [markdown]
# Given a list of values, there are several ways to count the frequency of each value.

# %%
t = [1, 2, 2, 3, 5]

# %% [markdown]
# You can use a Python dictionary:

# %%
hist = {}
for x in t:
    hist[x] = hist.get(x, 0) + 1
    
hist
# Out:
# {1: 1, 2: 2, 3: 1, 5: 1}

# %% [markdown]
# You can use a `Counter` (which is a dictionary with additional methods):

# %%
from collections import Counter
counter = Counter(t)
list(counter.keys())
# Out:
# [1, 2, 3, 5]

# %%
import matplotlib.pyplot as plot
plot.hist(list(counter.keys()), weights=list(counter.values()))
# Out:
# (array([ 1.,  0.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
sorted(counter.items(), key=lambda pair: pair[0], reverse=True)
# Out:
# [(5, 1), (3, 1), (2, 2), (1, 1)]

# %% [markdown]
# Or you can use the `Hist` object provided by `thinkstats2`:

# %%
import thinkstats2
hist = thinkstats2.Hist([1, 2, 2, 3, 5])
hist
# Out:
# Hist({1: 1, 2: 2, 3: 1, 5: 1})

# %% [markdown]
# `Hist` provides `Freq`, which looks up the frequency of a value.

# %%
hist.Freq(2)
# Out:
# 2

# %% [markdown]
# You can also use the bracket operator, which does the same thing.

# %%
hist[2]
# Out:
# 2

# %% [markdown]
# If the value does not appear, it has frequency 0.

# %%
hist[4]
# Out:
# 0

# %% [markdown]
# The `Values` method returns the values:

# %%
hist.Values()
# Out:
# dict_keys([1, 2, 3, 5])

# %% [markdown]
# So you can iterate the values and their frequencies like this:

# %%
for val in sorted(hist.Values()):
    print(val, hist[val])
# Out:
# 1 1
# 2 2
# 3 1
# 5 1

# %% [markdown]
# Or you can use the `Items` method:

# %%
for val, freq in hist.Items():
     print(val, freq)
# Out:
# 1 1
# 2 2
# 3 1
# 5 1

# %% [markdown]
# `thinkplot` is a wrapper for `matplotlib` that provides functions that work with the objects in `thinkstats2`.
#
# For example `Hist` plots the values and their frequencies as a bar graph.
#
# `Config` takes parameters that label the x and y axes, among other things.

# %%
import thinkplot
thinkplot.Hist(hist)
thinkplot.Config(xlabel='value', ylabel='frequency')

# %% [markdown]
# As an example, I'll replicate some of the figures from the book.
#
# First, I'll load the data from the pregnancy file and select the records for live births.

# %%
preg = nsfg.ReadFemPreg()
live = preg[preg.outcome == 1]

# %%
live
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# 11         14         1        NaN        NaN       NaN       NaN       6.0
# 12         14         2        NaN        NaN       NaN       NaN       6.0
# 15         15         2        NaN        NaN       NaN       NaN       6.0
# 16         15         3        NaN        NaN       NaN       NaN       6.0
# 17         18         1        NaN        NaN       NaN       NaN       5.0
# 19         21         1        NaN        NaN       NaN       NaN       6.0
# 20         21         2        NaN        NaN       NaN       NaN       6.0
# 21         23         1        NaN        NaN       NaN       NaN       6.0
# 23         24         1        NaN        NaN       NaN       NaN       6.0
# 24         24         2        NaN        NaN       NaN       NaN       6.0
# 25         24         3        NaN        NaN       NaN       NaN       6.0
# 26         28         1        NaN        NaN       NaN       NaN       6.0
# 27         31         1        NaN        NaN       NaN       NaN       6.0
# 28         31         2        NaN        NaN       NaN       NaN       6.0
# 29         31         3        NaN        NaN       NaN       NaN       6.0
# 31         36         2        NaN        NaN       NaN       NaN       6.0
# 32         38         1        NaN        NaN       NaN       NaN       5.0
# 33         38         2        NaN        NaN       NaN       NaN       6.0
# 34         38         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13548   12539         2        NaN        NaN       NaN       NaN       5.0
# 13551   12541         1        NaN        NaN       NaN       NaN       6.0
# 13552   12541         2        NaN        NaN       NaN       NaN       6.0
# 13553   12541         3        NaN        NaN       NaN       NaN       6.0
# 13554   12541         4        NaN        NaN       NaN       NaN       6.0
# 13555   12544         1        NaN        NaN       NaN       NaN       5.0
# 13556   12544         2        NaN        NaN       NaN       NaN       5.0
# 13557   12544         3        NaN        NaN       NaN       NaN       5.0
# 13559   12545         2        NaN        NaN       NaN       NaN       6.0
# 13560   12546         1        NaN        NaN       NaN       NaN       6.0
# 13561   12546         2        NaN        NaN       NaN       NaN       6.0
# 13562   12547         1        NaN        NaN       NaN       NaN       6.0
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# 13574   12561         2        NaN        NaN       NaN       NaN       6.0
# 13576   12565         1        NaN        NaN       NaN       NaN       6.0
# 13578   12566         1        NaN        NaN       NaN       NaN       6.0
# 13579   12566         2        NaN        NaN       NaN       NaN       6.0
# 13581   12568         2        NaN        NaN       NaN       NaN       5.0
# 13584   12569         2        NaN        NaN       NaN       NaN       6.0
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
#        pregend2  nbrnaliv  multbrth     ...       laborfor_i  religion_i  \
# 0           NaN       1.0       NaN     ...                0           0
# 1           NaN       1.0       NaN     ...                0           0
# 2           NaN       3.0       5.0     ...                0           0
# 3           NaN       1.0       NaN     ...                0           0
# 0          NaN       8.8125
# 1          NaN       7.8750
# 2          NaN       9.1250
# 3          NaN       7.0000
# 4          NaN       6.1875
# 5          NaN       8.5625
# 6          NaN       9.5625
# 7          NaN       8.3750
# 8          NaN       7.5625
# 9          NaN       6.6250
# 10         NaN       7.8125
# 11         NaN       7.0000
# 12         NaN       4.0000
# 15         NaN       7.6875
# 16         NaN       7.5000
# 17         NaN       6.3125
# 19         NaN       8.7500
# 20         NaN       8.1875
# 21         NaN       5.5625
# 23         NaN       6.7500
# 24         NaN       7.3750
# 25         NaN       6.8125
# 26         NaN       8.1250
# 27         NaN       7.1250
# 28         NaN       6.0625
# 29         NaN       7.4375
# 31         NaN       8.0000
# 32         NaN       7.5000
# 33         NaN       7.2500
# 34         NaN       7.1250
# ...        ...          ...
# 13548      NaN      10.0625
# 13551      NaN       5.3750
# 13552      NaN          NaN
# 13553      NaN       7.5000
# 13554      NaN          NaN
# 13555      NaN       6.1250
# 13556      NaN       7.1250
# 13557      NaN       6.5000
# 13559      NaN       7.8750
# 13560      NaN       7.8750
# 13561      NaN       6.8750
# 13562      NaN       8.1250
# 13563      NaN       7.6875
# 13564      NaN       7.6250
# 13565      NaN       8.1250
# 13566      NaN       7.5000
# 13569      NaN       5.8125
# 13570      NaN       6.6875
# 13571      NaN       6.0000
# 13572      NaN       5.8125
# 13573      NaN       6.5625
# 13574      NaN       6.1250
# 13576      NaN       6.4375
# 13578      NaN       6.0000
# 13579      NaN       7.0000
# 13581      NaN       6.3750
# 13584      NaN       6.3750
# 13588      NaN       6.1875
# 13591      NaN       7.5000
# 13592      NaN       7.5000
#
# [9148 rows x 244 columns]

# %% [markdown]
# Here's the histogram of birth weights in pounds.  Notice that `Hist` works with anything iterable, including a Pandas Series.  The `label` attribute appears in the legend when you plot the `Hist`.

# %%
hist = thinkstats2.Hist(live.birthwgt_lb, label='birthwgt_lb')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Birth weight (pounds)', ylabel='Count')

# %%
counter = Counter(live.birthwgt_lb).most_common()
counter = dict(filter(lambda pair: pair[0]>=0, counter))
plot.hist(list(counter.keys()), weights=list(counter.values()), bins=2*len(counter))
counter.values(), hist
# Out:
# (dict_values([3049, 2223, 1889, 697, 623, 229, 132, 98, 53, 40, 26, 10, 8, 3, 3, 1]),
#  Hist({7.0: 3049, 6.0: 2223, 8.0: 1889, 5.0: 697, 9.0: 623, 4.0: 229, 10.0: 132, 3.0: 98, 2.0: 53, 1.0: 40, 11.0: 26, 12.0: 10, 0.0: 8, 13.0: 3, 14.0: 3, 15.0: 1}))

# %% [markdown]
# Before plotting the ages, I'll apply `floor` to round down:

# %%
ages = np.floor(live.agepreg)

# %%
hist = thinkstats2.Hist(ages, label='agepreg')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='years', ylabel='Count')

# %% [markdown]
# As an exercise, plot the histogram of pregnancy lengths (column `prglngth`).

# %%
# Solution goes here
counter = Counter(live.prglngth).most_common()
counter = dict(filter(lambda pair: pair[0]>0, counter))
keys= list(counter.keys())
plot.hist(keys, weights=list(counter.values()), bins=2 * len(counter))
# Out:
# (array([  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   7.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   1.30000000e+01,   3.00000000e+00,
#           0.00000000e+00,   3.50000000e+01,   0.00000000e+00,
#           3.00000000e+00,   3.20000000e+01,   0.00000000e+00,
#           2.10000000e+01,   1.38000000e+02,   0.00000000e+00,
#           2.70000000e+01,   1.15000000e+02,   0.00000000e+00,
#           4.90000000e+01,   6.00000000e+01,   0.00000000e+00,
#           3.11000000e+02,   0.00000000e+00,   3.21000000e+02,
#           4.55000000e+02,   0.00000000e+00,   6.07000000e+02,
#           4.69300000e+03,   0.00000000e+00,   1.11600000e+03,
#           5.87000000e+02,   0.00000000e+00,   3.28000000e+02,
#           0.00000000e+00,   1.48000000e+02,   4.60000000e+01,
#           0.00000000e+00,   1.00000000e+01,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   7.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.00000000e+00]),
#  array([  4.        ,   4.63888889,   5.27777778,   5.91666667,
#           6.55555556,   7.19444444,   7.83333333,   8.47222222,
#           9.11111111,   9.75      ,  10.38888889,  11.02777778,
#          11.66666667,  12.30555556,  12.94444444,  13.58333333,
#          14.22222222,  14.86111111,  15.5       ,  16.13888889,
#          16.77777778,  17.41666667,  18.05555556,  18.69444444,
#          19.33333333,  19.97222222,  20.61111111,  21.25      ,
#          21.88888889,  22.52777778,  23.16666667,  23.80555556,
#          24.44444444,  25.08333333,  25.72222222,  26.36111111,
#          27.        ,  27.63888889,  28.27777778,  28.91666667,
#          29.55555556,  30.19444444,  30.83333333,  31.47222222,
#          32.11111111,  32.75      ,  33.38888889,  34.02777778,
#          34.66666667,  35.30555556,  35.94444444,  36.58333333,
#          37.22222222,  37.86111111,  38.5       ,  39.13888889,
#          39.77777778,  40.41666667,  41.05555556,  41.69444444,
#          42.33333333,  42.97222222,  43.61111111,  44.25      ,
#          44.88888889,  45.52777778,  46.16666667,  46.80555556,
#          47.44444444,  48.08333333,  48.72222222,  49.36111111,  50.        ]),
#  <a list of 72 Patch objects>)

# %% [markdown]
# `Hist` provides smallest, which select the lowest values and their frequencies.

# %%
for weeks, freq in hist.Smallest(10):
    print(weeks, freq)
# Out:
# 10.0 2
# 11.0 1
# 12.0 1
# 13.0 14
# 14.0 43
# 15.0 128
# 16.0 242
# 17.0 398
# 18.0 546
# 19.0 559

# %% [markdown]
# Use `Largest` to display the longest pregnancy lengths.

# %%
# Solution goes here
for weeks, freq in hist.Largest(10):
    print(weeks, freq)
# Out:
# 15.0 1
# 14.0 3
# 13.0 3
# 12.0 10
# 11.0 26
# 10.0 132
# 9.0 623
# 8.0 1889
# 7.0 3049
# 6.0 2223

# %% [markdown]
# From live births, we can selection first babies and others using `birthord`, then compute histograms of pregnancy length for the two groups.

# %%
firsts = live[live.birthord == 1]
others = live[live.birthord != 1]

first_hist = thinkstats2.Hist(firsts.prglngth, label='first')
other_hist = thinkstats2.Hist(others.prglngth, label='other')

# %% [markdown]
# We can use `width` and `align` to plot two histograms side-by-side.

# %%
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Hist(first_hist, align='right', width=width)
thinkplot.Hist(other_hist, align='left', width=width)
thinkplot.Config(xlabel='weeks', ylabel='Count', xlim=[27, 46])

# %% [markdown]
# `Series` provides methods to compute summary statistics:

# %%
mean = live.prglngth.mean()
var = live.prglngth.var()
std = live.prglngth.std()

# %% [markdown]
# Here are the mean and standard deviation:

# %%
mean, std, var
# Out:
# (38.56055968517709, 2.702343810070587, 7.3026620678268168)

# %% [markdown]
# As an exercise, confirm that `std` is the square root of `var`:

# %%
# Solution goes here
import math
math.sqrt(var)
# Out:
# 2.702343810070587

# %% [markdown]
# Here's are the mean pregnancy lengths for first babies and others:

# %%
firsts.prglngth.mean(), others.prglngth.mean()
# Out:
# (38.600951733514613, 38.522914466737063)

# %% [markdown]
# And here's the difference (in weeks):

# %%
firsts.prglngth.mean() - others.prglngth.mean()
# Out:
# 0.078037266777549519

# %% [markdown]
# This functon computes the Cohen effect size, which is the difference in means expressed in number of standard deviations:

# %%
def CohenEffectSize(group1, group2):
    """Computes Cohen's effect size for two groups.
    
    group1: Series or DataFrame
    group2: Series or DataFrame
    
    returns: float if the arguments are Series;
             Series if the arguments are DataFrames
    """
    diff = group1.mean() - group2.mean()

    var1 = group1.var()
    var2 = group2.var()
    n1, n2 = len(group1), len(group2)

    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    d = diff / np.sqrt(pooled_var)
    return d

# %% [markdown]
# Compute the Cohen effect size for the difference in pregnancy length for first babies and others.

# %%
# Solution goes here
CohenEffectSize(firsts.prglngth, others.prglngth)
# Out:
# 0.028879044654449834

# %% [markdown]
# ## Exercises

# %% [markdown]
# Using the variable `totalwgt_lb`, investigate whether first babies are lighter or heavier than others.
#
# Compute Cohen’s effect size to quantify the difference between the groups.  How does it compare to the difference in pregnancy length?

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# For the next few exercises, we'll load the respondent file:

# %%
resp = nsfg.ReadFemResp()

# %% [markdown]
# Make a histogram of <tt>totincr</tt> the total income for the respondent's family.  To interpret the codes see the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=FEM&section=R&subSec=7876&srtLabel=607543).

# %%
# Solution goes here

# %% [markdown]
# Make a histogram of <tt>age_r</tt>, the respondent's age at the time of interview.

# %%
# Solution goes here

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
# Solution goes here

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number of children borne by the respondent.  How would you describe this distribution?

# %%
# Solution goes here

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
# Solution goes here

# %% [markdown]
# Let's investigate whether people with higher income have higher parity.  Keep in mind that in this study, we are observing different people at different times during their lives, so this data is not the best choice for answering this question.  But for now let's take it at face value.
#
# Use <tt>totincr</tt> to select the respondents with the highest income (level 14).  Plot the histogram of <tt>parity</tt> for just the high income respondents.

# %%
# Solution goes here

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
# Solution goes here

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
# Solution goes here

# %% [markdown]
# Compute the Cohen effect size for this difference.  How does it compare with the difference in pregnancy length for first babies and others?

# %%
# Solution goes here
